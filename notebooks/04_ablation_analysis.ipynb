# %% [markdown]
# # 04. Comprehensive Ablation Matrix Analysis
#
# Analyzes parameter capacity (width vs depth), learning rate sensitivity, and SDE formulations.

# %%
from src.visualization.comparison import generate_leaderboard_table
from src.evaluation.metrics import load_metrics_from_csv

df = load_metrics_from_csv('results/metrics/results.csv')
leaderboard = generate_leaderboard_table(df, sort_by='fid')
display(leaderboard)
